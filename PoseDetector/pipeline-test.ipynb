# %%
import cv2
import csv
import mediapipe as mp
import numpy as np
import os
import json
class PoseDetector:
    """
    A class to detect pose landmarks from an image.
    """
    def __init__(self, static_image_mode=False, model_complexity=1, smooth_landmarks=True,
                 enable_segmentation=False, smooth_segmentation=True,
                 min_detection_confidence=0.5, min_tracking_confidence=0.5):
        self.static_image_mode = static_image_mode
        self.model_complexity = model_complexity
        self.smooth_landmarks = smooth_landmarks
        self.enable_segmentation = enable_segmentation
        self.smooth_segmentation = smooth_segmentation
        self.min_detection_confidence = min_detection_confidence
        self.min_tracking_confidence = min_tracking_confidence

        self.mp_pose = mp.solutions.pose
        self.pose = self.mp_pose.Pose(self.static_image_mode, self.model_complexity,
                                      self.smooth_landmarks, self.enable_segmentation,
                                      self.smooth_segmentation, self.min_detection_confidence,
                                      self.min_tracking_confidence)
        self.mp_draw = mp.solutions.drawing_utils

    def find_pose(self, img, draw=True):
        """
        Finds pose landmarks in an image.
        """
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        self.results = self.pose.process(img_rgb)
        if self.results.pose_landmarks and draw:
            self.mp_draw.draw_landmarks(img, self.results.pose_landmarks,
                                        self.mp_pose.POSE_CONNECTIONS)
        return img

    def get_landmarks(self, img):
        """
        Extracts pose landmarks from the image.
        """
        landmarks = []
        if self.results.pose_landmarks:
            for lm_id, lm in enumerate(self.results.pose_landmarks.landmark):
                h, w, c = img.shape
                cx, cy = int(lm.x * w), int(lm.y * h)
                landmarks.append([lm_id, cx, cy])
        return landmarks

def calculate_angle(a, b, c):
    """
    Calculates the angle between three points.
    """
    a = np.array(a)  # First
    b = np.array(b)  # Mid
    c = np.array(c)  # End

    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - \
              np.arctan2(a[1] - b[1], a[0] - b[0])
    angle = np.abs(radians * 180.0 / np.pi)

    if angle > 180.0:
        angle = 360 - angle

    return angle

def analyze_video(frames,video_id):
    """
    Analyzes a list of video frames for squats and push-ups.
    """
    detector = PoseDetector()
    squat_counter = 0
    pushup_counter = 0
    squat_stage = None
    pushup_stage = None
    squat_form_issues = []
    pushup_form_issues = []
    frame_data = []

    for idx, frame in enumerate(frames):
        frame = detector.find_pose(frame, draw=False)
        landmarks = detector.get_landmarks(frame)
        is_form_ok_this_frame = True
        if not landmarks:
            continue

        # Squat analysis
        left_hip = landmarks[23][1:]
        left_knee = landmarks[25][1:]
        left_ankle = landmarks[27][1:]
        knee_angle = calculate_angle(left_hip, left_knee, left_ankle)

        if knee_angle > 160:
            squat_stage = "up"
        if knee_angle < 90 and squat_stage == 'up':
            squat_stage = "down"
            squat_counter += 1
            # Form check
            if abs(left_knee[0] - left_ankle[0]) > 40: # Simplified check
                squat_form_issues.append("INSUFFICIENT_DEPTH")
                is_form_ok_this_frame = False

        # Push-up analysis
        left_shoulder = landmarks[11][1:]
        left_elbow = landmarks[13][1:]
        left_wrist = landmarks[15][1:]
        elbow_angle = calculate_angle(left_shoulder, left_elbow, left_wrist)

        if elbow_angle > 160:
            pushup_stage = "up"
        if elbow_angle < 90 and pushup_stage == 'up':
            pushup_stage = "down"
            pushup_counter += 1
            # Form check
            hip_shoulder_ankle_alignment = abs(left_hip[1] - left_shoulder[1])
            if hip_shoulder_ankle_alignment > 40: # Simplified check
                pushup_form_issues.append("BODY_LINE_BREAK")
                is_form_ok_this_frame = False
        # save frame data
        frame_data.append({
            "frame_index": idx,
            "exercise": "squat" if knee_angle < 160 else "pushup" if elbow_angle < 160 else "none",
            "rep_id": squat_counter if knee_angle < 160 else pushup_counter if elbow_angle < 160 else 0,
            "is_form_ok": is_form_ok_this_frame,
            "angles": {"knee": knee_angle, "elbow": elbow_angle}
        })

    # save the analysis summary
    analysis_summary = {
            "squats": {
                "total_reps": squat_counter,
                "good_form_reps": squat_counter - len(set(squat_form_issues)),
                "common_issues": list(set(squat_form_issues))
            },
            "pushups": {
                "total_reps": pushup_counter,
                "good_form_reps": pushup_counter - len(set(pushup_form_issues)),
                "common_issues": list(set(pushup_form_issues))
            }
        }
    
    summary_video_id = {"video_id": video_id,
        "summary": analysis_summary,}

    # Create output directory
    output_dir = " report/"
    os.makedirs(output_dir, exist_ok=True)

    # 1️⃣ Save frame-by-frame data to CSV
    csv_path = os.path.join(output_dir, "result.csv")
    with open(csv_path, mode='w', newline='') as csv_file:
        if frame_data:
            writer = csv.DictWriter(csv_file, fieldnames= frame_data[0].keys())
            writer.writeheader()
            writer.writerows(frame_data)

    # 2️⃣ Save summary block to JSON
    summary_path = os.path.join(output_dir, "summary.json")
    with open(summary_path, 'w') as json_file:
        json.dump(summary_video_id, json_file, indent=4)

    return {
        "video_id": video_id,
        "summary": analysis_summary,
        "frame_data": frame_data
    }

# %%
def main(video_path):
    """
    Main function to run the video analysis.

    Args:
        video_path (str): The path to the video file.
    """
    # Use OpenCV to capture the video
    cap = cv2.VideoCapture(video_path)

    # Check if the video was opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video file at {video_path}")
        return

    # Read all frames from the video into a list
    frames = []
    while True:
        # Read one frame
        success, frame = cap.read()
        
        # If the frame was not read successfully, we've reached the end of the video
        if not success:
            break
        
        # Add the frame to our list
        frames.append(frame)
    
    # Release the video capture object
    cap.release()

    # Make sure we have frames to analyze
    if not frames:
        print("Error: No frames were read from the video.")
        return

    print(f"Read {len(frames)} frames from the video. Starting analysis...")

    # Call the analysis function with the list of frames
    analysis_results = analyze_video(frames,video_path)

    # Print the results in a nicely formatted way
    print("\n--- Analysis Complete ---")
    print(json.dumps(analysis_results, indent=4))
    print("-----------------------\n")


if __name__ == '__main__':

    video_file_path = 'Squats.mp4' 
    # video_file_path = 'Push-ups.mp4' 
    main(video_file_path)

# %% [markdown]
# ## web service (Flask API Layer)

# %%
from flask import Flask, request, jsonify
import tempfile
import cv2
import os
import json

app = Flask(__name__)

@app.route('/analyze', methods=['POST'])
def analyze():
    # Check if video is included in the request
    if 'video' not in request.files:
        return jsonify({'error': 'No video file provided'}), 400

    video = request.files['video']

    # Check if a file was selected
    if video.filename == '':
        return jsonify({'error': 'No video file selected'}), 400

    # Use a temp file to store the uploaded video
    with tempfile.NamedTemporaryFile(suffix='.mp4', delete=False) as temp_file:
        video.save(temp_file)
        temp_filename = temp_file.name

    try:
        # Open the video file with OpenCV
        cap = cv2.VideoCapture(temp_filename)

        if not cap.isOpened():
            return jsonify({'error': 'Could not open video file'}), 400

        # Read all frames
        frames = []
        while True:
            success, frame = cap.read()
            if not success:
                break
            frames.append(frame)

        cap.release()

        if not frames:
            return jsonify({'error': 'No frames were read from the video'}), 400

        print(f"Read {len(frames)} frames from the video. Starting analysis...")

        # Call your custom video analysis function
        analysis_results = analyze_video(frames, video.filename)

        print("\n--- Analysis Complete ---")
        print(json.dumps(analysis_results, indent=4))
        print("-----------------------\n")

        return jsonify(analysis_results)

    finally:
        # Always remove the temporary file
        if os.path.exists(temp_filename):
            os.remove(temp_filename)

# %%
if __name__ == '__main__':
    # Run the app.
    app.run(debug=True,use_reloader=False, host='127.0.0.1', port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# Read 280 frames from the video. Starting analysis...
#
# --- Analysis Complete ---
# {
#     "video_id": "Squats.mp4",
#     "summary": {
#         "squats": {
#             "total_reps": 5,
#             "good_form_reps": 4,
#             "common_issues": [
#                 "INSUFFICIENT_DEPTH"
#             ]
#         },
#         "pushups": {
#             "total_reps": 0,
#             "good_form_reps": 0,
#             "common_issues": []
#         }
#     },
#     "frame_data": [
#         {
#             "frame_index": 0,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 172.72190927040856,
#                 "elbow": 105.32165123363335
#             }
#         },
#         {
#             "frame_index": 1,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 171.90696253095572,
#                 "elbow": 114.17410047024723
#             }
#         },
#         {
#             "frame_index": 2,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 169.6879005269131,
#                 "elbow": 114.10897077933753
#             }
#         },
#         {
#             "frame_index": 3,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 162.47491307727375,
#                 "elbow": 108.92252398570976
#             }
#         },
#         {
#             "frame_index": 4,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 153.36880720306382,
#                 "elbow": 110.85700078929989
#             }
#         },
#         {
#             "frame_index": 5,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 144.1651119329144,
#                 "elbow": 87.86691783381734
#             }
#         },
#         {
#             "frame_index": 6,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 135.45486999503046,
#                 "elbow": 73.61541110992147
#             }
#         },
#         {
#             "frame_index": 7,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 126.095713548547,
#                 "elbow": 65.68530620275362
#             }
#         },
#         {
#             "frame_index": 8,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 120.88295008682286,
#                 "elbow": 60.31143308733505
#             }
#         },
#         {
#             "frame_index": 9,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 113.32818230187851,
#                 "elbow": 55.26663584001443
#             }
#         },
#         {
#             "frame_index": 10,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 104.30917943770228,
#                 "elbow": 52.73699854292007
#             }
#         },
#         {
#             "frame_index": 11,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 100.34387012114388,
#                 "elbow": 49.17911225768354
#             }
#         },
#         {
#             "frame_index": 12,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 95.30195680923379,
#                 "elbow": 42.04595539450156
#             }
#         },
#         {
#             "frame_index": 13,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": false,
#             "angles": {
#                 "knee": 88.67135144044437,
#                 "elbow": 37.94912091338421
#             }
#         },
#         {
#             "frame_index": 14,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 83.0787917003866,
#                 "elbow": 39.9868862449642
#             }
#         },
#         {
#             "frame_index": 15,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 78.62105069653393,
#                 "elbow": 39.88469779575902
#             }
#         },
#         {
#             "frame_index": 16,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 74.16718373048906,
#                 "elbow": 38.332930909964205
#             }
#         },
#         {
#             "frame_index": 17,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 71.29699035901206,
#                 "elbow": 43.83127382691456
#             }
#         },
#         {
#             "frame_index": 18,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 67.48797010144705,
#                 "elbow": 43.200399593180144
#             }
#         },
#         {
#             "frame_index": 19,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 62.321040566071815,
#                 "elbow": 39.38681815324321
#             }
#         },
#         {
#             "frame_index": 20,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 59.41596174209076,
#                 "elbow": 39.0588067839158
#             }
#         },
#         {
#             "frame_index": 21,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 56.330656502306624,
#                 "elbow": 36.780699486863526
#             }
#         },
#         {
#             "frame_index": 22,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 54.968855865965,
#                 "elbow": 36.12736728134243
#             }
#         },
#         {
#             "frame_index": 23,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 54.20756071591717,
#                 "elbow": 38.76858036739039
#             }
#         },
#         {
#             "frame_index": 24,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 53.121636308357154,
#                 "elbow": 37.94769399215881
#             }
#         },
#         {
#             "frame_index": 25,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 52.96940566212896,
#                 "elbow": 37.250481171778205
#             }
#         },
#         {
#             "frame_index": 26,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 53.96912927787872,
#                 "elbow": 34.66942524021652
#             }
#         },
#         {
#             "frame_index": 27,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 56.17837790817282,
#                 "elbow": 36.1990017331056
#             }
#         },
#         {
#             "frame_index": 28,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 56.955011663967184,
#                 "elbow": 37.35207088876502
#             }
#         },
#         {
#             "frame_index": 29,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 61.42039253528975,
#                 "elbow": 52.77108262509021
#             }
#         },
#         {
#             "frame_index": 30,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 65.93766955963576,
#                 "elbow": 49.726003060631776
#             }
#         },
#         {
#             "frame_index": 31,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 70.91961244519428,
#                 "elbow": 52.96344377646289
#             }
#         },
#         {
#             "frame_index": 32,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 77.74739665962369,
#                 "elbow": 60.98451632329725
#             }
#         },
#         {
#             "frame_index": 33,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 85.22531067778613,
#                 "elbow": 66.56555800219986
#             }
#         },
#         {
#             "frame_index": 34,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 91.07276485804073,
#                 "elbow": 71.23415963870376
#             }
#         },
#         {
#             "frame_index": 35,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 97.0723415186527,
#                 "elbow": 68.97249284067935
#             }
#         },
#         {
#             "frame_index": 36,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 105.16118222133295,
#                 "elbow": 69.83047079028645
#             }
#         },
#         {
#             "frame_index": 37,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 112.82776984195044,
#                 "elbow": 65.72964695770393
#             }
#         },
#         {
#             "frame_index": 38,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 118.375049805717,
#                 "elbow": 67.81676226142709
#             }
#         },
#         {
#             "frame_index": 39,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 126.3373720728645,
#                 "elbow": 68.72105160995491
#             }
#         },
#         {
#             "frame_index": 40,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 133.07271293913539,
#                 "elbow": 67.84010000435919
#             }
#         },
#         {
#             "frame_index": 41,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 140.06741467451806,
#                 "elbow": 75.23524565775399
#             }
#         },
#         {
#             "frame_index": 42,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 146.89491815393404,
#                 "elbow": 78.81392331989906
#             }
#         },
#         {
#             "frame_index": 43,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 153.67077461016112,
#                 "elbow": 87.52748924868003
#             }
#         },
#         {
#             "frame_index": 44,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 160.42306293862075,
#                 "elbow": 91.62556526824457
#             }
#         },
#         {
#             "frame_index": 45,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 167.40845936371267,
#                 "elbow": 94.36325902366417
#             }
#         },
#         {
#             "frame_index": 46,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 173.81321923736292,
#                 "elbow": 96.28987503384208
#             }
#         },
#         {
#             "frame_index": 47,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 175.95963922570536,
#                 "elbow": 99.80871263320124
#             }
#         },
#         {
#             "frame_index": 48,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 178.87157423004712,
#                 "elbow": 101.40279046188675
#             }
#         },
#         {
#             "frame_index": 49,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 179.52517775162656,
#                 "elbow": 101.65727084760594
#             }
#         },
#         {
#             "frame_index": 50,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 179.95499566596686,
#                 "elbow": 110.94590898961455
#             }
#         },
#         {
#             "frame_index": 51,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 179.0130988007727,
#                 "elbow": 99.99397362204348
#             }
#         },
#         {
#             "frame_index": 52,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 177.92934386912052,
#                 "elbow": 101.03945214010733
#             }
#         },
#         {
#             "frame_index": 53,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 176.7443823683547,
#                 "elbow": 101.43179350082183
#             }
#         },
#         {
#             "frame_index": 54,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 174.79789331912698,
#                 "elbow": 107.1833614586216
#             }
#         },
#         {
#             "frame_index": 55,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 171.994654532557,
#                 "elbow": 106.36323596601694
#             }
#         },
#         {
#             "frame_index": 56,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 164.01921224312824,
#                 "elbow": 101.00698030927244
#             }
#         },
#         {
#             "frame_index": 57,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 156.19769063978524,
#                 "elbow": 74.72837108669746
#             }
#         },
#         {
#             "frame_index": 58,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 148.4780353618987,
#                 "elbow": 78.2000912486334
#             }
#         },
#         {
#             "frame_index": 59,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 139.100488217176,
#                 "elbow": 76.04499025259207
#             }
#         },
#         {
#             "frame_index": 60,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 130.90260064461197,
#                 "elbow": 73.5620495630118
#             }
#         },
#         {
#             "frame_index": 61,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 125.27231379367657,
#                 "elbow": 69.18580779787447
#             }
#         },
#         {
#             "frame_index": 62,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 115.83683958830935,
#                 "elbow": 63.66903847643307
#             }
#         },
#         {
#             "frame_index": 63,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 107.48034906824404,
#                 "elbow": 53.26469985362042
#             }
#         },
#         {
#             "frame_index": 64,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 103.55874208185293,
#                 "elbow": 44.92705417194827
#             }
#         },
#         {
#             "frame_index": 65,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 97.31798403749013,
#                 "elbow": 43.183947573850745
#             }
#         },
#         {
#             "frame_index": 66,
#             "exercise": "squat",
#             "rep_id": 1,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 90.20512060064948,
#                 "elbow": 41.14319901441015
#             }
#         },
#         {
#             "frame_index": 67,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": false,
#             "angles": {
#                 "knee": 86.90371838845897,
#                 "elbow": 41.2868464913795
#             }
#         },
#         {
#             "frame_index": 68,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 81.61793438057674,
#                 "elbow": 41.16046566914614
#             }
#         },
#         {
#             "frame_index": 69,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 75.88774967230552,
#                 "elbow": 41.51544743585353
#             }
#         },
#         {
#             "frame_index": 70,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 71.51083570927028,
#                 "elbow": 40.05848516792746
#             }
#         },
#         {
#             "frame_index": 71,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 67.76464873289865,
#                 "elbow": 42.905121296714356
#             }
#         },
#         {
#             "frame_index": 72,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 64.87015122771004,
#                 "elbow": 49.62156396456951
#             }
#         },
#         {
#             "frame_index": 73,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 59.75309261960268,
#                 "elbow": 48.512179516867626
#             }
#         },
#         {
#             "frame_index": 74,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 55.87505824799416,
#                 "elbow": 49.981879060708515
#             }
#         },
#         {
#             "frame_index": 75,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 52.9038008419418,
#                 "elbow": 50.794897376332194
#             }
#         },
#         {
#             "frame_index": 76,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 50.64780806327224,
#                 "elbow": 51.49236579972894
#             }
#         },
#         {
#             "frame_index": 77,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 49.862559503059856,
#                 "elbow": 55.7134630903912
#             }
#         },
#         {
#             "frame_index": 78,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 50.43738343883052,
#                 "elbow": 56.47869716861288
#             }
#         },
#         {
#             "frame_index": 79,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 52.598950309960856,
#                 "elbow": 58.204385040250045
#             }
#         },
#         {
#             "frame_index": 80,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 53.56785177576603,
#                 "elbow": 57.488085768948515
#             }
#         },
#         {
#             "frame_index": 81,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 53.557846927273374,
#                 "elbow": 57.897809126304104
#             }
#         },
#         {
#             "frame_index": 82,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 57.797603745509605,
#                 "elbow": 59.15839779979074
#             }
#         },
#         {
#             "frame_index": 83,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 61.10377487152323,
#                 "elbow": 56.34175874436176
#             }
#         },
#         {
#             "frame_index": 84,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 66.38480334913191,
#                 "elbow": 61.79061331106283
#             }
#         },
#         {
#             "frame_index": 85,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 72.828804505177,
#                 "elbow": 63.70704342369586
#             }
#         },
#         {
#             "frame_index": 86,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 78.9962605254945,
#                 "elbow": 59.5837145202078
#             }
#         },
#         {
#             "frame_index": 87,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 85.96545664077644,
#                 "elbow": 73.15421065195433
#             }
#         },
#         {
#             "frame_index": 88,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 92.91973433413597,
#                 "elbow": 76.14877351033039
#             }
#         },
#         {
#             "frame_index": 89,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 99.3566070835567,
#                 "elbow": 76.59379172014731
#             }
#         },
#         {
#             "frame_index": 90,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 107.49508073816759,
#                 "elbow": 88.22482614072503
#             }
#         },
#         {
#             "frame_index": 91,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 115.20632427237632,
#                 "elbow": 87.37609485495823
#             }
#         },
#         {
#             "frame_index": 92,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 119.94931981791512,
#                 "elbow": 86.16623520873733
#             }
#         },
#         {
#             "frame_index": 93,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 127.23579367874135,
#                 "elbow": 81.29102216153453
#             }
#         },
#         {
#             "frame_index": 94,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 134.1467251090891,
#                 "elbow": 85.76763265490558
#             }
#         },
#         {
#             "frame_index": 95,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 140.6353970460144,
#                 "elbow": 88.33830549673404
#             }
#         },
#         {
#             "frame_index": 96,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 148.13163991848685,
#                 "elbow": 91.7468259557143
#             }
#         },
#         {
#             "frame_index": 97,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 153.84513997542962,
#                 "elbow": 98.89523725008213
#             }
#         },
#         {
#             "frame_index": 98,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 158.4860389199344,
#                 "elbow": 103.17454265290334
#             }
#         },
#         {
#             "frame_index": 99,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 166.06706736111386,
#                 "elbow": 105.60971470720189
#             }
#         },
#         {
#             "frame_index": 100,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 170.78741547405394,
#                 "elbow": 104.07301605188253
#             }
#         },
#         {
#             "frame_index": 101,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 173.3276023920376,
#                 "elbow": 101.90643674971336
#             }
#         },
#         {
#             "frame_index": 102,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 176.55527774034434,
#                 "elbow": 107.11247303486124
#             }
#         },
#         {
#             "frame_index": 103,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 177.1161767970933,
#                 "elbow": 108.63304360910338
#             }
#         },
#         {
#             "frame_index": 104,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 177.5195046928981,
#                 "elbow": 109.39436345412805
#             }
#         },
#         {
#             "frame_index": 105,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 178.1124347594874,
#                 "elbow": 108.79233652351192
#             }
#         },
#         {
#             "frame_index": 106,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 177.23121569288602,
#                 "elbow": 108.4110115198727
#             }
#         },
#         {
#             "frame_index": 107,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 176.53281324290631,
#                 "elbow": 106.2567731720443
#             }
#         },
#         {
#             "frame_index": 108,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 175.5239741752558,
#                 "elbow": 104.6298408029429
#             }
#         },
#         {
#             "frame_index": 109,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 170.64856523966134,
#                 "elbow": 101.74869183227601
#             }
#         },
#         {
#             "frame_index": 110,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 159.10941616694447,
#                 "elbow": 100.43295483138627
#             }
#         },
#         {
#             "frame_index": 111,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 151.5514906741414,
#                 "elbow": 89.57473041318661
#             }
#         },
#         {
#             "frame_index": 112,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 143.12628588441956,
#                 "elbow": 82.14361537034506
#             }
#         },
#         {
#             "frame_index": 113,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 135.6983357692618,
#                 "elbow": 76.41946337877492
#             }
#         },
#         {
#             "frame_index": 114,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 128.91958520228664,
#                 "elbow": 77.86084959737885
#             }
#         },
#         {
#             "frame_index": 115,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 124.66505286756978,
#                 "elbow": 74.09387003502931
#             }
#         },
#         {
#             "frame_index": 116,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 117.38480177940357,
#                 "elbow": 70.14382953777412
#             }
#         },
#         {
#             "frame_index": 117,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 109.28024601962377,
#                 "elbow": 57.45136215481236
#             }
#         },
#         {
#             "frame_index": 118,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 102.52381447744216,
#                 "elbow": 59.53905247377246
#             }
#         },
#         {
#             "frame_index": 119,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 98.10830492719174,
#                 "elbow": 55.44256067876227
#             }
#         },
#         {
#             "frame_index": 120,
#             "exercise": "squat",
#             "rep_id": 2,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 92.60330674417952,
#                 "elbow": 50.35421523904444
#             }
#         },
#         {
#             "frame_index": 121,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": false,
#             "angles": {
#                 "knee": 85.51649343494051,
#                 "elbow": 45.76622327630805
#             }
#         },
#         {
#             "frame_index": 122,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 80.65215412750109,
#                 "elbow": 46.36798932906103
#             }
#         },
#         {
#             "frame_index": 123,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 75.0936603770046,
#                 "elbow": 43.533933169245714
#             }
#         },
#         {
#             "frame_index": 124,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 70.14351201579495,
#                 "elbow": 41.09620700762789
#             }
#         },
#         {
#             "frame_index": 125,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 66.75739717010714,
#                 "elbow": 41.922424277802264
#             }
#         },
#         {
#             "frame_index": 126,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 62.45698367511113,
#                 "elbow": 43.02286362593954
#             }
#         },
#         {
#             "frame_index": 127,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 56.41797350073546,
#                 "elbow": 44.84546818929535
#             }
#         },
#         {
#             "frame_index": 128,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 53.399423674070306,
#                 "elbow": 47.32113844440989
#             }
#         },
#         {
#             "frame_index": 129,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 50.49382156347832,
#                 "elbow": 49.36720552167802
#             }
#         },
#         {
#             "frame_index": 130,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 48.051258254565695,
#                 "elbow": 53.09894211077541
#             }
#         },
#         {
#             "frame_index": 131,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 48.79575960830874,
#                 "elbow": 41.09960117899906
#             }
#         },
#         {
#             "frame_index": 132,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 49.38317999729662,
#                 "elbow": 38.5600382943794
#             }
#         },
#         {
#             "frame_index": 133,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 50.60905204183888,
#                 "elbow": 52.975056926988174
#             }
#         },
#         {
#             "frame_index": 134,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 51.14721313091957,
#                 "elbow": 58.19398270511201
#             }
#         },
#         {
#             "frame_index": 135,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 52.103317512782155,
#                 "elbow": 56.32087388234176
#             }
#         },
#         {
#             "frame_index": 136,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 53.05798090156395,
#                 "elbow": 56.43945728684935
#             }
#         },
#         {
#             "frame_index": 137,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 59.89965022957233,
#                 "elbow": 59.74941848302797
#             }
#         },
#         {
#             "frame_index": 138,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 64.26613185613536,
#                 "elbow": 58.28214756408827
#             }
#         },
#         {
#             "frame_index": 139,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 69.84637082826612,
#                 "elbow": 61.09151834816005
#             }
#         },
#         {
#             "frame_index": 140,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 75.79552547771192,
#                 "elbow": 63.159874665248786
#             }
#         },
#         {
#             "frame_index": 141,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 82.73234319556536,
#                 "elbow": 68.7510027280161
#             }
#         },
#         {
#             "frame_index": 142,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 90.19554797627086,
#                 "elbow": 74.98946363432967
#             }
#         },
#         {
#             "frame_index": 143,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 96.04278941520823,
#                 "elbow": 75.94289160800838
#             }
#         },
#         {
#             "frame_index": 144,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 102.25335845369693,
#                 "elbow": 77.95436761473421
#             }
#         },
#         {
#             "frame_index": 145,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 110.29038954483372,
#                 "elbow": 77.95792176236257
#             }
#         },
#         {
#             "frame_index": 146,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 117.39734226823191,
#                 "elbow": 83.700838731919
#             }
#         },
#         {
#             "frame_index": 147,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 122.31985691050056,
#                 "elbow": 80.11023921518739
#             }
#         },
#         {
#             "frame_index": 148,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 128.90663044038575,
#                 "elbow": 83.62237906469728
#             }
#         },
#         {
#             "frame_index": 149,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 133.43243376006373,
#                 "elbow": 85.44335483160255
#             }
#         },
#         {
#             "frame_index": 150,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 139.96931671381623,
#                 "elbow": 88.51607195422105
#             }
#         },
#         {
#             "frame_index": 151,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 147.05147474223295,
#                 "elbow": 88.45184230102204
#             }
#         },
#         {
#             "frame_index": 152,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 154.90282794505447,
#                 "elbow": 99.1389135815702
#             }
#         },
#         {
#             "frame_index": 153,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 160.73278502210235,
#                 "elbow": 98.5700646608316
#             }
#         },
#         {
#             "frame_index": 154,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 167.4262157854923,
#                 "elbow": 106.97307090748481
#             }
#         },
#         {
#             "frame_index": 155,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 172.48632431483068,
#                 "elbow": 107.5217034353151
#             }
#         },
#         {
#             "frame_index": 156,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 174.91969720365202,
#                 "elbow": 110.75964487172625
#             }
#         },
#         {
#             "frame_index": 157,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 177.6150387277029,
#                 "elbow": 109.9312316235973
#             }
#         },
#         {
#             "frame_index": 158,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 179.50087470296546,
#                 "elbow": 111.49174850461202
#             }
#         },
#         {
#             "frame_index": 159,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 179.85855031073208,
#                 "elbow": 110.89274013533583
#             }
#         },
#         {
#             "frame_index": 160,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 179.5339811052758,
#                 "elbow": 112.75559223727052
#             }
#         },
#         {
#             "frame_index": 161,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 179.27505918660765,
#                 "elbow": 111.1216071263851
#             }
#         },
#         {
#             "frame_index": 162,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 177.89492578175512,
#                 "elbow": 109.34658990654543
#             }
#         },
#         {
#             "frame_index": 163,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 176.88233580683786,
#                 "elbow": 105.95460674989766
#             }
#         },
#         {
#             "frame_index": 164,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 174.68241282317865,
#                 "elbow": 109.93426549239302
#             }
#         },
#         {
#             "frame_index": 165,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 167.86276452829327,
#                 "elbow": 105.17565165344082
#             }
#         },
#         {
#             "frame_index": 166,
#             "exercise": "pushup",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 161.38591997331446,
#                 "elbow": 99.01710836093586
#             }
#         },
#         {
#             "frame_index": 167,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 152.37410960749463,
#                 "elbow": 90.12882114814644
#             }
#         },
#         {
#             "frame_index": 168,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 145.18254006930275,
#                 "elbow": 81.09000659462858
#             }
#         },
#         {
#             "frame_index": 169,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 138.4298121147982,
#                 "elbow": 81.10196155801518
#             }
#         },
#         {
#             "frame_index": 170,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 129.7701982711377,
#                 "elbow": 78.17166924471765
#             }
#         },
#         {
#             "frame_index": 171,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 125.00090493474951,
#                 "elbow": 70.05777556136695
#             }
#         },
#         {
#             "frame_index": 172,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 118.51191809073683,
#                 "elbow": 72.80022692977289
#             }
#         },
#         {
#             "frame_index": 173,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 110.06294329870408,
#                 "elbow": 70.3927074256364
#             }
#         },
#         {
#             "frame_index": 174,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 103.14187302154613,
#                 "elbow": 67.03526851222509
#             }
#         },
#         {
#             "frame_index": 175,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 98.46162368964866,
#                 "elbow": 64.03042431535555
#             }
#         },
#         {
#             "frame_index": 176,
#             "exercise": "squat",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 90.86466631387731,
#                 "elbow": 61.52516199565963
#             }
#         },
#         {
# ...
#                 "elbow": 160.36216694893116
#             }
#         },
#         {
#             "frame_index": 232,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 153.40329821199083,
#                 "elbow": 136.376528318625
#             }
#         },
#         {
#             "frame_index": 233,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 152.55118342304388,
#                 "elbow": 161.80500417887714
#             }
#         },
#         {
#             "frame_index": 234,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 149.72977075948012,
#                 "elbow": 176.02955996739482
#             }
#         },
#         {
#             "frame_index": 235,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 147.49994333904272,
#                 "elbow": 177.6554525105415
#             }
#         },
#         {
#             "frame_index": 236,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 149.84754908256198,
#                 "elbow": 142.88141038963377
#             }
#         },
#         {
#             "frame_index": 237,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 150.29354193568474,
#                 "elbow": 147.92694000905198
#             }
#         },
#         {
#             "frame_index": 238,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 148.42437005503228,
#                 "elbow": 20.86131905634168
#             }
#         },
#         {
#             "frame_index": 239,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 151.54975975018982,
#                 "elbow": 19.388960100123494
#             }
#         },
#         {
#             "frame_index": 240,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 153.4157975645016,
#                 "elbow": 16.93657588394227
#             }
#         },
#         {
#             "frame_index": 241,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 154.65855611779753,
#                 "elbow": 17.4655082018033
#             }
#         },
#         {
#             "frame_index": 242,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 155.5034384901644,
#                 "elbow": 14.997653808953858
#             }
#         },
#         {
#             "frame_index": 243,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 155.4811509701025,
#                 "elbow": 18.05282001500848
#             }
#         },
#         {
#             "frame_index": 244,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 157.73357298959186,
#                 "elbow": 76.35585155411573
#             }
#         },
#         {
#             "frame_index": 245,
#             "exercise": "pushup",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 161.3749134383926,
#                 "elbow": 34.29360838905544
#             }
#         },
#         {
#             "frame_index": 246,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 159.24826226135704,
#                 "elbow": 28.52506502587587
#             }
#         },
#         {
#             "frame_index": 247,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 159.51772581023087,
#                 "elbow": 25.22760882550885
#             }
#         },
#         {
#             "frame_index": 248,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 151.78247592117998,
#                 "elbow": 17.985534186058544
#             }
#         },
#         {
#             "frame_index": 249,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 152.3137120582954,
#                 "elbow": 17.24001805611575
#             }
#         },
#         {
#             "frame_index": 250,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 157.67173820721663,
#                 "elbow": 16.620550771699186
#             }
#         },
#         {
#             "frame_index": 251,
#             "exercise": "pushup",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 160.19241771730935,
#                 "elbow": 18.56687939637654
#             }
#         },
#         {
#             "frame_index": 252,
#             "exercise": "pushup",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 162.53906323736643,
#                 "elbow": 19.666801304396483
#             }
#         },
#         {
#             "frame_index": 253,
#             "exercise": "pushup",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 160.9770272279852,
#                 "elbow": 20.310934197331587
#             }
#         },
#         {
#             "frame_index": 254,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 159.6079398698515,
#                 "elbow": 21.80539106961131
#             }
#         },
#         {
#             "frame_index": 255,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 159.84552846894152,
#                 "elbow": 21.568850583248985
#             }
#         },
#         {
#             "frame_index": 256,
#             "exercise": "pushup",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 160.30816179230027,
#                 "elbow": 21.051493629963662
#             }
#         },
#         {
#             "frame_index": 257,
#             "exercise": "pushup",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 161.03472766427595,
#                 "elbow": 21.56255405082045
#             }
#         },
#         {
#             "frame_index": 258,
#             "exercise": "pushup",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 166.15374512803893,
#                 "elbow": 24.73441401901647
#             }
#         },
#         {
#             "frame_index": 259,
#             "exercise": "pushup",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 168.77123163795602,
#                 "elbow": 22.586668246268786
#             }
#         },
#         {
#             "frame_index": 260,
#             "exercise": "pushup",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 168.85271317287882,
#                 "elbow": 12.33571400603707
#             }
#         },
#         {
#             "frame_index": 261,
#             "exercise": "pushup",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 170.14857614734242,
#                 "elbow": 26.022713816327737
#             }
#         },
#         {
#             "frame_index": 262,
#             "exercise": "pushup",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 171.6829546247279,
#                 "elbow": 82.20187038852906
#             }
#         },
#         {
#             "frame_index": 263,
#             "exercise": "pushup",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 166.349200489689,
#                 "elbow": 105.03202676181402
#             }
#         },
#         {
#             "frame_index": 264,
#             "exercise": "pushup",
#             "rep_id": 3,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 161.99353941550393,
#                 "elbow": 122.80124154334237
#             }
#         },
#         {
#             "frame_index": 265,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 151.33964429318192,
#                 "elbow": 134.5817362627049
#             }
#         },
#         {
#             "frame_index": 266,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 152.15828689652247,
#                 "elbow": 154.26023338841915
#             }
#         },
#         {
#             "frame_index": 267,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 153.86391127816688,
#                 "elbow": 162.194830309644
#             }
#         },
#         {
#             "frame_index": 268,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 150.62384191202244,
#                 "elbow": 164.3483589891025
#             }
#         },
#         {
#             "frame_index": 269,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 156.3156063576868,
#                 "elbow": 179.6328655943352
#             }
#         },
#         {
#             "frame_index": 270,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 153.14257976407464,
#                 "elbow": 173.45692162570992
#             }
#         },
#         {
#             "frame_index": 271,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 158.7667935371538,
#                 "elbow": 179.5433255545736
#             }
#         },
#         {
#             "frame_index": 272,
#             "exercise": "squat",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 157.84639007874407,
#                 "elbow": 178.54330444933615
#             }
#         },
#         {
#             "frame_index": 273,
#             "exercise": "none",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 163.02396671382863,
#                 "elbow": 175.84923007945264
#             }
#         },
#         {
#             "frame_index": 274,
#             "exercise": "none",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 166.3331835758262,
#                 "elbow": 171.39161669137505
#             }
#         },
#         {
#             "frame_index": 275,
#             "exercise": "none",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 168.10830903818356,
#                 "elbow": 173.56247975216388
#             }
#         },
#         {
#             "frame_index": 276,
#             "exercise": "none",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 161.90373765987394,
#                 "elbow": 177.1496799756621
#             }
#         },
#         {
#             "frame_index": 277,
#             "exercise": "none",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 163.94674045354745,
#                 "elbow": 178.17822493030155
#             }
#         },
#         {
#             "frame_index": 278,
#             "exercise": "none",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 177.2801313896859,
#                 "elbow": 178.46104838156398
#             }
#         },
#         {
#             "frame_index": 279,
#             "exercise": "none",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 172.5666584015205,
#                 "elbow": 175.78898573441154
#             }
#         },
#         {
#             "frame_index": 280,
#             "exercise": "none",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 174.3575728542472,
#                 "elbow": 176.74465644713496
#             }
#         },
#         {
#             "frame_index": 281,
#             "exercise": "none",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 166.27310840261754,
#                 "elbow": 179.12704473213887
#             }
#         },
#         {
#             "frame_index": 282,
#             "exercise": "none",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 174.78354335953563,
#                 "elbow": 179.26546874203652
#             }
#         },
#         {
#             "frame_index": 283,
#             "exercise": "none",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 176.79111522770074,
#                 "elbow": 179.5133531047086
#             }
#         },
#         {
#             "frame_index": 284,
#             "exercise": "none",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 175.14874284462775,
#                 "elbow": 179.9140102302427
#             }
#         },
#         {
#             "frame_index": 285,
#             "exercise": "none",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 178.5446721329946,
#                 "elbow": 178.95141011393042
#             }
#         },
#         {
#             "frame_index": 286,
#             "exercise": "none",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 176.7336656925542,
#                 "elbow": 179.4008513495677
#             }
#         },
#         {
#             "frame_index": 287,
#             "exercise": "none",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 164.72214938799289,
#                 "elbow": 179.86374394410916
#             }
#         },
#         {
#             "frame_index": 288,
#             "exercise": "none",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 162.83945871407371,
#                 "elbow": 179.57221778094305
#             }
#         },
#         {
#             "frame_index": 289,
#             "exercise": "none",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 163.64599458743137,
#                 "elbow": 179.86715146145806
#             }
#         },
#         {
#             "frame_index": 290,
#             "exercise": "none",
#             "rep_id": 0,
#             "is_form_ok": true,
#             "angles": {
#                 "knee": 166.5215588394629,
#                 "elbow": 179.38270116443897
#             }
#         }
#     ]
# }
# -----------------------
# 127.0.0.1 - - [09/Aug/2025 10:10:12] "POST /analyze HTTP/1.1" 200 -

# %%
# call endpoint from terminal 
#  http --form POST http://127.0.0.1:5000/analyze video@c:/Users/Islam/Downloads/PoseDetector/input_video/Squats.mp4
# http --form POST http://127.0.0.1:5000/analyze video@c:/Users/Islam/Downloads/PoseDetector/input_video/Push-ups.mp4
